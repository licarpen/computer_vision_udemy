# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('my_new_picture.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# recall that OpenCV expects order of colors to be Blue Green Red
# to convert color ordering:  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread('my_new_picture.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (650, 975)

# %%
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(img)

# %%
new_image = cv2.resize(img, (500, 200))

# %%
plt.imshow(new_image)

# %%
# resizing with ratios
new_image = cv2.resize(img,(0,0),img, 0.5, 0.25)

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (162, 488, 3)

# %%
new_img = cv2.flip(img, 0)
plt.imshow(new_img)

# %%
cv2.imwrite('flipped_dog.jpg', new_img)
# Out:
# True

# %%
# designate canvas size for displaying images in notebook
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(new_img)
